# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tmp
# Out:
# (8, 8, 8, 8) -------
# b'\x00\xfa\x00\xfa\x00\x03'
# []

# %%
im = Image.open("C:/Users/KIRIL/OneDrive/Рабочий стол/1.jpg")
im = np.array(im)

# %%
c = tmp.compress(im)
r, g, b = tmp.decompress(c)
decomp_im = tmp.
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=853x1280>
